# %%
print("🚀 RES-Q Orchestrator Initializing...")
# Out:
# 🚀 RES-Q Orchestrator Initializing...

# %%
# ===== PATH SAFETY CELL (MANDATORY FOR ORCHESTRATION) =====

import os

# Force project root as working directory
PROJECT_ROOT = os.getcwd()

while not os.path.exists(os.path.join(PROJECT_ROOT, "README.md")):
    PROJECT_ROOT = os.path.dirname(PROJECT_ROOT)

os.chdir(PROJECT_ROOT)

print("✅ Feature notebook working directory set to:", os.getcwd())
# Out:
# ✅ Feature notebook working directory set to: d:\Study\Learn ML\DL\ResQ

# %%
os.listdir("data/raw")
# Out:
# ['disaster_response_messages_test.csv',
#  'disaster_response_messages_training.csv',
#  'disaster_response_messages_validation.csv']

# %%
# Load Feature-1: Disaster Type Detection
# %run "./features/disaster detection feature.ipynb"

# Load Feature-2: Fake / Reliability Detection
# %run "./features/disaster_reliable.ipynb"

# Load Feature-3 & Feature-4: Severity + Priority
# %run "./features/severity_signal.ipynb"

# Load Feature-5: Summarization
# %run "./features/summarisation.ipynb"

print("✅ All feature notebooks loaded successfully")
# Out:
# Device set to use cuda:0
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_23304\392231847.py:3
#       1 import os
# ----> 3 print(os.listdir("../data/raw"))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '../data/raw'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Load Feature-1: Disaster Type Detection
# ----> 2 get_ipython().run_line_magic('run', '"./features/disaster detection feature.ipynb"')
#       4 # Load Feature-2: Fake / Reliability Detection
#       5 get_ipython().run_line_magic('run', '"./features/disaster_reliable.ipynb"')
#
# ...

# %%
import os

print("Current Working Directory:")
print(os.getcwd())
# Out:
# Current Working Directory:
# d:\Study\Learn ML\DL\ResQ
